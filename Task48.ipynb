# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy import stats
import statsmodels.api as sm
from sklearn.preprocessing import PowerTransformer

# %%
df = pd.read_csv('Data_to_Transform.csv')
df.head()
# Out:
#    Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                0.899990              2.895074               11.180748
# 1                1.113554              2.962385               10.842938
# 2                1.156830              2.966378               10.817934
# 3                1.264131              3.000324               10.764570
# 4                1.323914              3.012109               10.753117
#
#    Highly Negative Skew
# 0              9.027485
# 1              9.009762
# 2              9.006134
# 3              9.000125
# 4              8.981296

# %%
sns.histplot(df['Moderate Positive Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Moderate Positive Skew'])
sns.histplot(df_log)
fig = plt.figure()

# %%
df_cbrt = np.cbrt(df['Moderate Positive Skew'])
sns.histplot(df_cbrt)
fig = plt.figure()

# %%
data = df['Moderate Positive Skew'].values.reshape(-1, 1)

# %%
pt = PowerTransformer(method='box-cox')
df_boxcox = pt.fit_transform(data)

# %%
sns.histplot(df_boxcox)
fig = plt.figure()

# %%
fig = sm.qqplot(df_boxcox, line='45')
plt.show()

# %%
sns.histplot(df['Highly Positive Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Highly Positive Skew'])
sns.histplot(df_log)
fig = plt.figure()

# %%
data2 = df['Highly Positive Skew'].values.reshape(-1, 1)

# %%
pt = PowerTransformer(method='box-cox')
df_boxcox = pt.fit_transform(data2)

# %%
sns.histplot(df_boxcox)
fig = plt.figure()

# %%
fig = sm.qqplot(df_boxcox, line='45')
plt.show()

# %%
sns.histplot(df['Moderate Negative Skew'])
fig = plt.figure()

# %%
data3 = df['Moderate Negative Skew'].values.reshape(-1, 1)
x=data3

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
x = stats.loggamma.rvs(5, size=50) + 5
prob = stats.probplot(x, dist=stats.norm, plot=ax1)
ax1.set_xlabel('')
ax1.set_title('Probplot against normal distribution')

ax2 = fig.add_subplot(212)
xt, lmbda = stats.yeojohnson(x)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('Probplot after Yeo-Johnson transformation')
plt.show()

# %%
sns.histplot(xt)
fig = plt.figure()

# %%
data4 = df['Highly Negative Skew'].values.reshape(-1, 1)
x=data4

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
x = stats.loggamma.rvs(5, size=50) + 5
prob = stats.probplot(x, dist=stats.norm, plot=ax1)
ax1.set_xlabel('')
ax1.set_title('Probplot against normal distribution')

ax2 = fig.add_subplot(212)
xt, lmbda = stats.yeojohnson(x)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('Probplot after Yeo-Johnson transformation')
plt.show()

# %%
sns.histplot(xt)
fig = plt.figure()
